# %% [markdown]
# 1. Misra, Rishabh and Jigyasa Grover. "Do Not ‘Fake It Till You Make It’! Synopsis of Trending Fake News Detection Methodologies Using Deep Learning." Deep Learning for Social Media Data Analytics (2022).
# 2. Misra, Rishabh. "Politifact Fact Check Dataset." DOI: 10.13140/RG.2.2.29923.22566 (2022).

# %% [markdown]
# @incollection{misra2022not,
#   title={Do Not ‘Fake It Till You Make It’! Synopsis of Trending Fake News Detection Methodologies Using Deep Learning},
#   author={Misra, Rishabh and Grover, Jigyasa},
#   booktitle={Deep Learning for Social Media Data Analytics},
#   pages={213--235},
#   year={2022},
#   publisher={Springer}
# }
# @dataset{misra2022politifact,
#   author = {Misra, Rishabh},
#   year = {2022},
#   month = {09},
#   pages = {},
#   title = {Politifact Fact Check Dataset},
#   doi = {10.13140/RG.2.2.29923.22566}
# }

# %%
import pandas as pd
df = pd.read_excel('../../data/politifact_dataset/Politifact_dataset.xlsx') #lines=True

display(df)
# Out:
#        Unnamed: 0       verdict statement_originator  \
# 0               0          true         Barack Obama
# 1               1         false           Matt Gaetz
# 2               2   mostly-true         Kelly Ayotte
# 3               3         false             Bloggers
# 4               4     half-true         Bobby Jindal
# ...           ...           ...                  ...
# 21147       21147  mostly-false         Donald Trump
# 21148       21148         false     Donald Trump Jr.
# 21149       21149  mostly-false          Chris Abele
# 21150       21150         false             Bloggers
# 21151       21151  mostly-false       Facebook posts
#
#                                                statement statement_date  \
# 0      John McCain opposed bankruptcy protections for...      6/11/2008
# 1      "Bennie Thompson actively cheer-led riots in t...       6/7/2022
# 2      Says Maggie Hassan was "out of state on 30 day...      5/18/2016
# ...

# %% [markdown]
# Creating a random subset of a 1000 statements

# %%
# Sample 1000 random rows
sampled_df = df.sample(n=1000, random_state=1)

# If you want to save this sample to a new CSV file:
sampled_df.to_csv('../../data/politifact_dataset/politifact_1000_statements.csv', index=False)

# If you want to display the first few rows of the sampled DataFrame
display(sampled_df)
# Out:
#        Unnamed: 0      verdict   statement_originator  \
# 5343         5343         true  Norcross City Council
# 19939       19939        false           Donald Trump
# 8688         8688    half-true             Mark Kelly
# 1866         1866    half-true          Beto O'Rourke
# 2729         2729        false     Kimberley Strassel
# ...           ...          ...                    ...
# 153           153   pants-fire               Ted Cruz
# 18077       18077  mostly-true         Michael Morell
# 16719       16719        false            Nathan Deal
# 1662         1662        false  Defending Main Street
# 1480         1480         true             Rick Scott
#
#                                                statement statement_date  \
# 5343   The proposed raises for the Norcross City Coun...       5/9/2013
# 19939  Says 99% of COVID-19 cases "are totally harmle...       7/4/2020
# 8688   Says Martha McSally "voted to take away money ...      10/6/2020
# ...

# %%
pd.set_option('display.max_colwidth', None)
print(sampled_df['statement'])
# Out:
# 5343                                                                                                               The proposed raises for the Norcross City Council would put it in line with other liked-sized communities.
# 19939                                                                                                                                                                      Says 99% of COVID-19 cases "are totally harmless."
# 8688                                                                                                                            Says Martha McSally "voted to take away money from Fort Huachuca to pay for the border wall."
# 1866                                                                                                                                    El Paso is the "safest city in the state of Texas, safest city in the United States."
# ...
